# %%
from langchain.chains import GraphCypherQAChain
from langchain_community.graphs import Neo4jGraph
from langchain_openai import ChatOpenAI

# %%
graph = Neo4jGraph(
    url="neo4j://localhost:7687", username="neo4j", password="macneo4j", database='graph.db'
)

# %%
print(graph.schema)
# Out:
# Node properties are the following:
# DatabaseObject {dateTime: STRING, schemaClass: STRING, note: STRING, displayName: STRING, dbId: INTEGER, speciesName: STRING, startCoordinate: INTEGER, isInDisease: BOOLEAN, stIdVersion: STRING, name: LIST, referenceType: STRING, endCoordinate: INTEGER, stId: STRING, firstname: STRING, initial: STRING, surname: STRING, coordinate: INTEGER, oldStId: STRING, identifier: STRING, chain: LIST, databaseName: STRING, sequenceLength: INTEGER, description: LIST, url: STRING, geneName: LIST, checksum: STRING, comment: LIST, secondaryIdentifier: LIST, keyword: LIST, isSequenceChanged: BOOLEAN, isChimeric: BOOLEAN, text: STRING, volume: INTEGER, journal: STRING, pages: STRING, year: INTEGER, pubMedIdentifier: INTEGER, title: STRING, trivial: BOOLEAN, formula: STRING, releaseDate: STRING, isInferred: BOOLEAN, variantIdentifier: STRING, definition: STRING, accession: STRING, orcidId: STRING, ecNumber: STRING, releaseStatus: STRING, hasEHLD: BOOLEAN, hasDiagram: BOOLEAN, isOrdered: BOOLEAN, synonym: LIST, alteredAminoAcidFragment: STRING, endPositionInReferenceSequence: INTEGER, startPositionInReferenceSequence: INTEGER, diagramHeight: INTEGER, diagramWidth: INTEGER, approved: BOOLEAN, otherIdentifier: LIST},Event {schemaClass: STRING, speciesName: STRING, isInDisease: BOOLEAN, releaseDate: STRING, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, isChimeric: BOOLEAN, stId: STRING, isInferred: BOOLEAN, oldStId: STRING, releaseStatus: STRING, systematicName: STRING, hasEHLD: BOOLEAN, hasDiagram: BOOLEAN, doi: STRING, diagramHeight: INTEGER, diagramWidth: INTEGER, definition: STRING},Pathway {schemaClass: STRING, isInDisease: BOOLEAN, releaseDate: STRING, displayName: STRING, stId: STRING, speciesName: STRING, diagramHeight: INTEGER, hasEHLD: BOOLEAN, stIdVersion: STRING, dbId: INTEGER, releaseStatus: STRING, name: LIST, hasDiagram: BOOLEAN, isInferred: BOOLEAN, doi: STRING, diagramWidth: INTEGER, oldStId: STRING, definition: STRING},ReactionLikeEvent {schemaClass: STRING, speciesName: STRING, isInDisease: BOOLEAN, releaseDate: STRING, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, isChimeric: BOOLEAN, stId: STRING, isInferred: BOOLEAN, releaseStatus: STRING, oldStId: STRING, systematicName: STRING, definition: STRING},Reaction {schemaClass: STRING, speciesName: STRING, isInDisease: BOOLEAN, releaseDate: STRING, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, isChimeric: BOOLEAN, stId: STRING, isInferred: BOOLEAN, releaseStatus: STRING, oldStId: STRING, systematicName: STRING, definition: STRING},PhysicalEntity {schemaClass: STRING, speciesName: STRING, startCoordinate: INTEGER, isInDisease: BOOLEAN, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, referenceType: STRING, endCoordinate: INTEGER, stId: STRING, isChimeric: BOOLEAN, oldStId: STRING, systematicName: STRING, definition: STRING, minUnitCount: INTEGER, isOrdered: BOOLEAN},Complex {schemaClass: STRING, speciesName: STRING, isInDisease: BOOLEAN, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, isChimeric: BOOLEAN, stId: STRING, oldStId: STRING, systematicName: STRING, definition: STRING, isLoaded: BOOLEAN, preventLazyLoading: BOOLEAN},EntitySet {schemaClass: STRING, speciesName: STRING, oldStId: STRING, isInDisease: BOOLEAN, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, stId: STRING, isOrdered: BOOLEAN, systematicName: STRING},GenomeEncodedEntity {schemaClass: STRING, speciesName: STRING, startCoordinate: INTEGER, isInDisease: BOOLEAN, displayName: STRING, stIdVersion: STRING, dbId: INTEGER, name: LIST, referenceType: STRING, endCoordinate: INTEGER, stId: STRING, oldStId: STRING, systematicName: STRING, definition: STRING},ReferenceEntity {schemaClass: STRING, identifier: STRING, databaseName: STRING, displayName: STRING, dbId: INTEGER, geneName: LIST, url: STRING, sequenceLength: INTEGER, name: LIST, secondaryIdentifier: LIST, chain: LIST, description: LIST, chec ...
# Relationship properties are the following:
# author {stoichiometry: INTEGER, order: INTEGER},modified {stoichiometry: INTEGER, order: INTEGER},affiliation {stoichiometry: INTEGER, order: INTEGER},referenceDatabase {stoichiometry: INTEGER, order: INTEGER},created {stoichiometry: INTEGER, order: INTEGER},crossReference {stoichiometry: INTEGER, order: INTEGER},superTaxon {stoichiometry: INTEGER, order: INTEGER},species {stoichiometry: INTEGER, order: INTEGER},referenceGene {stoichiometry: INTEGER, order: INTEGER},referenceEntity {stoichiometry: INTEGER, order: INTEGER},instanceOf {stoichiometry: INTEGER, order: INTEGER},componentOf {stoichiometry: INTEGER, order: INTEGER},surroundedBy {stoichiometry: INTEGER, order: INTEGER},hasPart {stoichiometry: INTEGER, order: INTEGER},compartment {stoichiometry: INTEGER, order: INTEGER},hasComponent {stoichiometry: INTEGER, order: INTEGER},psiMod {stoichiometry: INTEGER, order: INTEGER},referenceSequence {stoichiometry: INTEGER, order: INTEGER},hasModifiedResidue {stoichiometry: INTEGER, order: INTEGER},input {stoichiometry: INTEGER, order: INTEGER},output {stoichiometry: INTEGER, order: INTEGER},authored {stoichiometry: INTEGER, order: INTEGER},edited {stoichiometry: INTEGER, order: INTEGER},precedingEvent {stoichiometry: INTEGER, order: INTEGER},literatureReference {stoichiometry: INTEGER, order: INTEGER},reviewed {stoichiometry: INTEGER, order: INTEGER},summation {stoichiometry: INTEGER, order: INTEGER},reviewStatus {stoichiometry: INTEGER, order: INTEGER},inferredTo {stoichiometry: INTEGER, order: INTEGER},hasEvent {stoichiometry: INTEGER, order: INTEGER},hasMember {stoichiometry: INTEGER, order: INTEGER},repeatedUnit {stoichiometry: INTEGER, order: INTEGER},modification {stoichiometry: INTEGER, order: INTEGER},activeUnit {stoichiometry: INTEGER, order: INTEGER},activity {stoichiometry: INTEGER, order: INTEGER},physicalEntity {stoichiometry: INTEGER, order: INTEGER},catalystActivity {stoichiometry: INTEGER, order: INTEGER},hasCandidate {stoichiometry: INTEGER, order: INTEGER},regulator {stoichiometry: INTEGER, order: INTEGER},regulatedBy {stoichiometry: INTEGER, order: INTEGER},regulation {stoichiometry: INTEGER, order: INTEGER},regulationReference {stoichiometry: INTEGER, order: INTEGER},goBiologicalProcess {stoichiometry: INTEGER, order: INTEGER},revised {stoichiometry: INTEGER, order: INTEGER},requiredInputComponent {stoichiometry: INTEGER, order: INTEGER},catalystActivityReference {stoichiometry: INTEGER, order: INTEGER},goCellularComponent {stoichiometry: INTEGER, order: INTEGER},structureModified {stoichiometry: INTEGER, order: INTEGER},includedLocation {stoichiometry: INTEGER, order: INTEGER},previousReviewStatus {stoichiometry: INTEGER, order: INTEGER},isoformParent {stoichiometry: INTEGER, order: INTEGER},disease {stoichiometry: INTEGER, order: INTEGER},relatedSpecies {stoichiometry: INTEGER, order: INTEGER},equivalentTo {stoichiometry: INTEGER, order: INTEGER},secondReferenceSequence {stoichiometry: INTEGER, order: INTEGER},figure {stoichiometry: INTEGER, order: INTEGER},reason {stoichiometry: INTEGER, order: INTEGER},negativePrecedingEvent {stoichiometry: INTEGER, order: INTEGER},publisher {stoichiometry: INTEGER, order: INTEGER},internalReviewed {stoichiometry: INTEGER, order: INTEGER},entityOnOtherCell {stoichiometry: INTEGER, order: INTEGER},reverseReaction {stoichiometry: INTEGER, order: INTEGER},hasEncapsulatedEvent {stoichiometry: INTEGER, order: INTEGER},reactionType {stoichiometry: INTEGER, order: INTEGER},evidenceType {stoichiometry: INTEGER, order: INTEGER},functionalStatusType {stoichiometry: INTEGER, order: INTEGER},structuralVariant {stoichiometry: INTEGER, order: INTEGER},functionalStatus {stoichiometry: INTEGER, order: INTEGER},diseaseEntity {stoichiometry: INTEGER, order: INTEGER},normalEntity {stoichiometry: INTEGER, order: INTEGER},entityFunctionalStatus {stoichiometry: INTEGER, order: INTEGER},normalReaction {stoichiometry: INTEGER, order: INTEGER},cellType {stoichiometry: INTEGER, order: INTEGER},norm ...
# The relationships are the following:
# (:DatabaseObject)-[:hasModifiedResidue]->(:DatabaseObject),(:DatabaseObject)-[:hasModifiedResidue]->(:TranslationalModification),(:DatabaseObject)-[:hasModifiedResidue]->(:AbstractModifiedResidue),(:DatabaseObject)-[:hasModifiedResidue]->(:GroupModifiedResidue),(:DatabaseObject)-[:hasModifiedResidue]->(:ModifiedResidue),(:DatabaseObject)-[:hasModifiedResidue]->(:ReplacedResidue),(:DatabaseObject)-[:hasModifiedResidue]->(:GeneticallyModifiedResidue),(:DatabaseObject)-[:hasModifiedResidue]->(:NonsenseMutation),(:DatabaseObject)-[:hasModifiedResidue]->(:FragmentModification),(:DatabaseObject)-[:hasModifiedResidue]->(:FragmentReplacedModification),(:DatabaseObject)-[:species]->(:DatabaseObject),(:DatabaseObject)-[:species]->(:Taxon),(:DatabaseObject)-[:species]->(:Species),(:DatabaseObject)-[:referenceEntity]->(:DatabaseObject),(:DatabaseObject)-[:referenceEntity]->(:ReferenceEntity),(:DatabaseObject)-[:referenceEntity]->(:ReferenceGeneProduct),(:DatabaseObject)-[:referenceEntity]->(:ReferenceSequence),(:DatabaseObject)-[:referenceEntity]->(:ReferenceMolecule),(:DatabaseObject)-[:referenceEntity]->(:ReferenceTherapeutic),(:DatabaseObject)-[:referenceEntity]->(:ReferenceDNASequence),(:DatabaseObject)-[:referenceEntity]->(:ReferenceRNASequence),(:DatabaseObject)-[:compartment]->(:DatabaseObject),(:DatabaseObject)-[:compartment]->(:Compartment),(:DatabaseObject)-[:compartment]->(:GO_CellularComponent),(:DatabaseObject)-[:compartment]->(:GO_Term),(:DatabaseObject)-[:modified]->(:DatabaseObject),(:DatabaseObject)-[:modified]->(:PhysicalEntity),(:DatabaseObject)-[:modified]->(:Complex),(:DatabaseObject)-[:modified]->(:Summation),(:DatabaseObject)-[:modified]->(:EntitySet),(:DatabaseObject)-[:modified]->(:DefinedSet),(:DatabaseObject)-[:modified]->(:Person),(:DatabaseObject)-[:modified]->(:GenomeEncodedEntity),(:DatabaseObject)-[:modified]->(:EntityWithAccessionedSequence),(:DatabaseObject)-[:modified]->(:LiteratureReference),(:DatabaseObject)-[:modified]->(:Publication),(:DatabaseObject)-[:modified]->(:SimpleEntity),(:DatabaseObject)-[:modified]->(:Event),(:DatabaseObject)-[:modified]->(:ReactionLikeEvent),(:DatabaseObject)-[:modified]->(:BlackBoxEvent),(:DatabaseObject)-[:modified]->(:Reaction),(:DatabaseObject)-[:modified]->(:ControlReference),(:DatabaseObject)-[:modified]->(:CatalystActivityReference),(:DatabaseObject)-[:modified]->(:CatalystActivity),(:DatabaseObject)-[:modified]->(:Cell),(:DatabaseObject)-[:modified]->(:MarkerReference),(:DatabaseObject)-[:modified]->(:AbstractModifiedResidue),(:DatabaseObject)-[:modified]->(:GeneticallyModifiedResidue),(:DatabaseObject)-[:modified]->(:FragmentModification),(:DatabaseObject)-[:modified]->(:FragmentReplacedModification),(:DatabaseObject)-[:modified]->(:InstanceEdit),(:DatabaseObject)-[:modified]->(:Regulation),(:DatabaseObject)-[:modified]->(:NegativeRegulation),(:DatabaseObject)-[:modified]->(:CandidateSet),(:DatabaseObject)-[:modified]->(:ModifiedResidue),(:DatabaseObject)-[:modified]->(:TranslationalModification),(:DatabaseObject)-[:modified]->(:ReferenceEntity),(:DatabaseObject)-[:modified]->(:ReferenceGeneProduct),(:DatabaseObject)-[:modified]->(:ReferenceSequence),(:DatabaseObject)-[:hasMember]->(:DatabaseObject),(:DatabaseObject)-[:hasMember]->(:PhysicalEntity),(:DatabaseObject)-[:hasMember]->(:EntitySet),(:DatabaseObject)-[:hasMember]->(:DefinedSet),(:DatabaseObject)-[:hasMember]->(:GenomeEncodedEntity),(:DatabaseObject)-[:hasMember]->(:EntityWithAccessionedSequence),(:DatabaseObject)-[:hasMember]->(:Complex),(:DatabaseObject)-[:hasMember]->(:SimpleEntity),(:DatabaseObject)-[:author]->(:DatabaseObject),(:DatabaseObject)-[:author]->(:LiteratureReference),(:DatabaseObject)-[:author]->(:Publication),(:DatabaseObject)-[:author]->(:InstanceEdit),(:DatabaseObject)-[:referenceDatabase]->(:DatabaseObject),(:DatabaseObject)-[:referenceDatabase]->(:ReferenceDatabase),(:DatabaseObject)-[:created]->(:DatabaseObject),(:DatabaseObject)-[:created]->(:Summation),(:DatabaseObject)-[:created] ...

# %%
chain = GraphCypherQAChain.from_llm(
    ChatOpenAI(temperature=0, model='gpt-4-0125-preview'), graph=graph, verbose=True
)

# %%
chain.run('List pathways annotated for gene TP53')
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (g:ReferenceGeneProduct)-[:referenceEntity]->(pe:PhysicalEntity)-[:input|output|catalystActivity|physicalEntity|regulatedBy|hasComponent*]->(p:Pathway)
# WHERE g.displayName = 'TP53'
# RETURN DISTINCT p.displayName AS PathwayName, p.stId AS StableID
#
# Full Context:
# []
#
# > Finished chain.
# "I don't know the answer."
